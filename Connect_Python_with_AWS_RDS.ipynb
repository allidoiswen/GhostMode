# %%
import pandas as pd
import csv
import datetime as dt
from sqlalchemy import create_engine
# from config import username, password

username = 'root'
password = 'postgres'

# create a connection engine
engine = create_engine(f'postgresql://{username}:{password}@db-creditcard.c0cdrlhmo9ac.us-east-2.rds.amazonaws.com/creditcard_db')

# Test pull from the database
test_df = pd.read_sql("SELECT * FROM creditcard LIMIT 10", con = engine)

test_df
# Out:
#       time        v1        v2        v3        v4        v5        v6  \
# 0  87731.0 -2.920884  2.723745 -1.207728 -2.786760 -0.302561 -1.334933
# 1  87732.0 -0.475446  1.132067  0.400849  1.216531  0.569272 -0.256415
# 2  87732.0 -1.816330  1.764823 -0.433532 -2.959324  0.616849 -0.651219
# 3  87732.0 -5.767451  5.348140 -3.527673 -3.154710  1.065238 -0.726167
# 4  87732.0 -1.222383  1.338253 -0.049203 -2.966737  0.968103 -0.655325
# 5  87733.0 -1.227760  1.405124 -0.376812 -2.173291  0.520277 -0.747276
# 6  87733.0 -1.786407  1.760306 -0.509314 -2.980778  0.635763 -0.744633
# 7  87734.0 -2.338294  1.928575 -0.283932 -2.956386  0.343480 -0.897061
# 8  87735.0 -0.912319 -0.266990  1.061565 -0.231552  0.422050 -0.155522
# 9  87735.0  1.787512  0.113979  0.157759  3.712868 -0.137282  0.838199
#
#          v7        v8        v9  ...       v22       v23       v24       v25  \
# 0  0.190649  1.141781  0.578954  ... -0.907005  0.122025  0.735892  0.340991
# 1  1.524616 -0.709272  0.134639  ...  0.416505 -0.096011 -0.263935 -0.585716
# 2  0.782905  0.468143  0.387902  ... -0.847756 -0.065209  0.277642  0.194262
# 3  1.970587 -0.650045  5.538599  ...  0.220347 -0.107136 -0.471898  1.009151
# 4  1.227215 -0.035659  0.411433  ... -0.858226 -0.225650 -1.032941  0.180295
# 5  1.026459 -0.372287  1.100603  ... -0.437291  0.224183  0.740745 -1.117422
# 6  0.830005  0.406961  0.435765  ... -0.893788 -0.171987 -1.037514  0.252534
# 7  0.879249  0.105696  1.026486  ... -0.837854  0.012736  0.723034  0.004887
# 8  0.273042  0.098296  0.605679  ...  1.047425  0.015250 -0.675502 -0.023427
# 9 -0.622382  0.291762 -0.493700  ...  0.852287  0.082028 -0.407276 -0.196740
#
#         v26       v27       v28  amount  class            id
# 0  0.369042  0.479056  0.351059    1.00    0.0  8.589935e+09
# 1 -0.657029 -0.396443 -0.146468  108.00    0.0  8.589935e+09
# 2  0.364542  0.513573  0.339075    1.00    0.0  8.589935e+09
# 3  0.068080  2.119373  0.468061    0.92    0.0  8.589935e+09
# 4  0.427720  0.540946  0.327484    5.00    0.0  8.589935e+09
# 5  0.255520 -0.175757  0.243261    5.00    0.0  8.589935e+09
# 6  0.434080  0.517978  0.326293    1.00    0.0  8.589935e+09
# 7  0.244811 -0.354568  0.128878    1.00    0.0  8.589935e+09
# 8 -0.066682  0.395558  0.255425  121.70    0.0  8.589935e+09
# 9  0.090643  0.010804 -0.041545   31.13    0.0  8.589935e+09
#
# [10 rows x 32 columns]
